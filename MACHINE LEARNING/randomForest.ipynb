# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
creditos = pd.read_csv('Credit.csv')
creditos.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = creditos.iloc[:,0:20].values
classe = creditos.iloc[:,20].values
for i in range (0,20):
    lencoder = LabelEncoder()
    if type(previsores[0,i]) == str:
        previsores[:,i] = lencoder.fit_transform(previsores[:,i])

# %%
x_treino,x_teste,y_treino,y_teste = train_test_split(previsores,classe,
                                    test_size=0.3,random_state=0)
previsores
# Out:
# array([[2, 6, 1, ..., 1, 1, 1],
#        [1, 48, 3, ..., 1, 0, 1],
#        [0, 12, 1, ..., 2, 0, 1],
#        ...,
#        [0, 12, 3, ..., 1, 0, 1],
#        [2, 45, 3, ..., 1, 1, 1],
#        [1, 45, 1, ..., 1, 0, 1]], dtype=object)

# %%
forest = RandomForestClassifier(n_estimators=100)
forest.fit(x_treino,y_treino)
# Out:
# RandomForestClassifier()

# %%
forest.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=2068500489),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1463144350),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1679296836),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1537390246),
#  DecisionTreeClassifier(max_features='sqrt', random_state=495463904),
#  DecisionTreeClassifier(max_features='sqrt', random_state=465076055),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2089753687),
#  DecisionTreeClassifier(max_features='sqrt', random_state=465027358),
#  DecisionTreeClassifier(max_features='sqrt', random_state=818030345),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1449234706),
#  DecisionTreeClassifier(max_features='sqrt', random_state=772124642),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2004604946),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1621087086),
#  DecisionTreeClassifier(max_features='sqrt', random_state=351433609),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2048990801),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1787500670),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1747841790),
#  DecisionTreeClassifier(max_features='sqrt', random_state=414078640),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1945236140),
#  DecisionTreeClassifier(max_features='sqrt', random_state=791367929),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1118971707),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2077802760),
#  DecisionTreeClassifier(max_features='sqrt', random_state=981242037),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1616621413),
#  DecisionTreeClassifier(max_features='sqrt', random_state=865824672),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1751686075),
#  DecisionTreeClassifier(max_features='sqrt', random_state=318663700),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1447849980),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1286154746),
#  DecisionTreeClassifier(max_features='sqrt', random_state=521813544),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1120929928),
#  DecisionTreeClassifier(max_features='sqrt', random_state=765585294),
#  DecisionTreeClassifier(max_features='sqrt', random_state=286501497),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1591862857),
#  DecisionTreeClassifier(max_features='sqrt', random_state=145751488),
#  DecisionTreeClassifier(max_features='sqrt', random_state=73998658),
#  DecisionTreeClassifier(max_features='sqrt', random_state=21730675),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1997381825),
#  DecisionTreeClassifier(max_features='sqrt', random_state=898711737),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1854335609),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1005126700),
#  DecisionTreeClassifier(max_features='sqrt', random_state=111590189),
#  DecisionTreeClassifier(max_features='sqrt', random_state=737314895),
#  DecisionTreeClassifier(max_features='sqrt', random_state=290852535),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1705062612),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1361149915),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1473162802),
#  DecisionTreeClassifier(max_features='sqrt', random_state=325355800),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1537631851),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1343559230),
#  DecisionTreeClassifier(max_features='sqrt', random_state=38925317),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1024083752),
#  DecisionTreeClassifier(max_features='sqrt', random_state=627686414),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1127384840),
#  DecisionTreeClassifier(max_features='sqrt', random_state=732634574),
#  DecisionTreeClassifier(max_features='sqrt', random_state=288263925),
#  DecisionTreeClassifier(max_features='sqrt', random_state=137022710),
#  DecisionTreeClassifier(max_features='sqrt', random_state=836498309),
#  DecisionTreeClassifier(max_features='sqrt', random_state=941899303),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1805477577),
#  DecisionTreeClassifier(max_features='sqrt', random_state=435337155),
#  DecisionTreeClassifier(max_features='sqrt', random_state=771709373),
#  DecisionTreeClassifier(max_features='sqrt', random_state=775628016),
#  DecisionTreeClassifier(max_features='sqrt', random_state=553340636),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2052426597),
#  DecisionTreeClassifier(max_features='sqrt', random_state=81687063),
#  DecisionTreeClassifier(max_features='sqrt', random_state=781463100),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1479401084),
#  DecisionTreeClassifier(max_features='sqrt', random_state=525929785),
#  DecisionTreeClassifier(max_features='sqrt', random_state=475972967),
#  DecisionTreeClassifier(max_features='sqrt', random_state=349042301),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1549619785),
#  DecisionTreeClassifier(max_features='sqrt', random_state=572455118),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1049957610),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1825676986),
#  DecisionTreeClassifier(max_features='sqrt', random_state=931349531),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2002388663),
#  DecisionTreeClassifier(max_features='sqrt', random_state=125006390),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1132033829),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1732627519),
#  DecisionTreeClassifier(max_features='sqrt', random_state=77454083),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1280338397),
#  DecisionTreeClassifier(max_features='sqrt', random_state=296952017),
#  DecisionTreeClassifier(max_features='sqrt', random_state=168691990),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1697318906),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1465280818),
#  DecisionTreeClassifier(max_features='sqrt', random_state=124902086),
#  DecisionTreeClassifier(max_features='sqrt', random_state=173284251),
#  DecisionTreeClassifier(max_features='sqrt', random_state=709891286),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1696823439),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1118739925),
#  DecisionTreeClassifier(max_features='sqrt', random_state=427488255),
#  DecisionTreeClassifier(max_features='sqrt', random_state=528391876),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1981525916),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1163208050),
#  DecisionTreeClassifier(max_features='sqrt', random_state=431911663),
#  DecisionTreeClassifier(max_features='sqrt', random_state=763880681),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1357062924),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1379625007),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1103996633)]

# %%
forest.estimators_[1]
# Out:
# DecisionTreeClassifier(max_features='sqrt', random_state=1463144350)

# %%
previsoes = forest.predict(x_teste)
accuracy = accuracy_score(y_teste,previsoes)
accuracy
# Out:
# 0.7766666666666666

# %%
confusao = confusion_matrix(y_teste,previsoes)
confusao
# Out:
# array([[ 36,  50],
#        [ 17, 197]])
