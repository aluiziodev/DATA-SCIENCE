# %%
import statistics as st
import pandas as pd
import numpy  as np

# %%
#1

def amplitude(V):
    return max(V) - min(V)

V = [1, 4, 5,6, 8, 10, 2, 12, 1]
if amplitude(V)==11:
    print("ok!")
else:
    print("erro!")
# Out:
# ok!

# %%
#2

def imprime(s):
    for i in range(len(s)):
        print(s[i])

s = "Python"
imprime(s)
# Out:
# P
# y
# t
# h
# o
# n

# %%
p = int(input())

if p<=10:
    print(50)
elif 10<p<=20:
    print(80)
else:
    print("Nao aceito")
# Out:
#  21
# Nao aceito
