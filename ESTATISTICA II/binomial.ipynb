# %%
from scipy.stats import binom

# %%
#jogar uma moeda 5 vezes, qual a probabilidade de sair 3 caras?
binom.pmf(3, 5, 0.5)
# Out:
# np.float64(0.31249999999999983)

# %%
#passar por 4 sinais de 4 tempos, qual a probabilidade de pegar sinal verde: nenhuma, 1, 2, 3, 4 vezes seguidas?
binom.pmf(0, 4, 0.25)
binom.pmf(1, 4, 0.25)
binom.pmf(2, 4, 0.25)
binom.pmf(3, 4, 0.25)
binom.pmf(4, 4, 0.25)
# Out:
# np.float64(0.00390625)

# %%
#sinais de dois tempos
binom.pmf(4, 4, 0.5)
# Out:
# np.float64(0.0625)

# %%
#prob acumlada
binom.cdf(3, 4, 0.25)
# Out:
# np.float64(0.99609375)

# %%
#concurso de 12 questões, qual a probabilidade de acertar 7 questões, chutando todas as respostas (4 alternativas)?
binom.pmf(7, 12, 0.25) * 100
# Out:
# np.float64(1.1471271514892587)

# %%
#prob de acertar todas
binom.pmf(12, 12, 0.25)
# Out:
# np.float64(5.960464477539063e-08)
