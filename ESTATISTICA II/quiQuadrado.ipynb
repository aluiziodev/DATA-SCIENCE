# %%
import numpy as np
from scipy.stats import chi2_contingency

# %%
#criando matriz com os dados
data = np.array([[43, 32],
                 [19, 6]])
data
# Out:
# array([[43, 32],
#        [19,  6]])

# %%
chi2_contingency(data)
# Out:
# Chi2ContingencyResult(statistic=np.float64(2.0373514431239386), pvalue=np.float64(0.15347667161786663), dof=1, expected_freq=array([[46.5, 28.5],
#        [15.5,  9.5]]))

# %%
data2 = np.array([[43, 32],
                 [22, 3]])
data2
# Out:
# array([[43, 32],
#        [22,  3]])

# %%
chi2_contingency(data2)
# Out:
# Chi2ContingencyResult(statistic=np.float64(6.461538461538462), pvalue=np.float64(0.011023416388221451), dof=1, expected_freq=array([[48.75, 26.25],
#        [16.25,  8.75]]))
