# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("trees.csv")
db.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
srn.histplot(db.Volume, color="Red",kde=True, stat="density", bins=10).set(title="Arvores")
# Out:
# [Text(0.5, 1.0, 'Arvores')]

# %%
db2 = pd.read_csv("chicken.csv")
db2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
agrp = db2.groupby(["feed"])["weight"].sum()
agrp
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
test = db2.loc[db2["feed"] == "horsebean"]
test
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
srn.kdeplot(db2.loc[db2["feed"] == "horsebean"]).set_title("horsebean")
# Out:
# Text(0.5, 1.0, 'horsebean')

# %%
srn.histplot(db2.loc[db2["feed"] == "casein"], kde=True).set_title("casein")
# Out:
# Text(0.5, 1.0, 'casein')

# %%
srn.histplot(db2.loc[db2["feed"] == "linseed"], kde=True).set_title("linseed")
# Out:
# Text(0.5, 1.0, 'linseed')

# %%
srn.histplot(db2.loc[db2["feed"] == "meatmeal"], kde=True).set_title("meatmeal")
# Out:
# Text(0.5, 1.0, 'meatmeal')

# %%
srn.histplot(db2.loc[db2["feed"] == "soybean"], kde=True).set_title("soybean")
# Out:
# Text(0.5, 1.0, 'soybean')

# %%
srn.histplot(db2.loc[db2["feed"] == "sunflower"], kde=True).set_title("sunflower")
# Out:
# Text(0.5, 1.0, 'sunflower')

# %%
plt.figure()
plt.subplot(3,2,1)
srn.histplot(db2.loc[db2["feed"] == "horsebean"].weight, kde=True).set_title("horsebean")
plt.subplot(3,2,2)
srn.histplot(db2.loc[db2["feed"] == "casein"].weight, kde=True).set_title("casein")
plt.subplot(3,2,3)
srn.histplot(db2.loc[db2["feed"] == "linseed"].weight, kde=True).set_title("linseed")
plt.subplot(3,2,4)
srn.histplot(db2.loc[db2["feed"] == "meatmeal"].weight, kde=True).set_title("meatmeal")
plt.subplot(3,2,5)
srn.histplot(db2.loc[db2["feed"] == "soybean"].weight, kde=True).set_title("soybean")
plt.subplot(3,2,6)
srn.histplot(db2.loc[db2["feed"] == "sunflower"].weight, kde=True).set_title("sunflower")
plt.tight_layout()
