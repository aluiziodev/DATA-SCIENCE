# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
database = pd.read_csv("trees.csv")
database.shape
# Out:
# (31, 3)

# %%
database.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
hist = np.histogram(database.iloc[:,1], bins=6)
hist
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
plt.hist(database.iloc[:,1], bins=6)
plt.title("Arvores")
plt.xlabel("ALtura")
plt.ylabel("Frequencia")
# Out:
# Text(0, 0.5, 'Frequencia')
