# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("trees.csv")
db.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.scatter(db.Girth, db.Volume)

# %%
plt.scatter(db.Girth, db.Height)

# %%
plt.scatter(db.Volume, db.Height, marker = '*')

# %%
plt.hist(db.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(1)
plt.subplot(3,3,7)
plt.scatter(db.Girth, db.Volume)
plt.subplot(3,3,2)
plt.scatter(db.Girth, db.Height)
plt.subplot(3,3,5)
plt.scatter(db.Volume, db.Height, marker = '*')
plt.subplot(3,3,9)
plt.hist(db.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)
