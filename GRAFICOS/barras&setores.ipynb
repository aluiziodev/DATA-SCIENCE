# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("insect.csv")
db.shape
# Out:
# (72, 2)

# %%
db.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
agrp = db.groupby(["spray"])["count"].sum()
agrp
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrp.plot.bar(color = "blue")
# Out:
# <Axes: xlabel='spray'>

# %%
agrp.plot.bar(color= ["red", "blue", "yellow", "green", "brown", "pink"])
# Out:
# <Axes: xlabel='spray'>

# %%
agrp.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
agrp.plot.pie(legend = True)
plt.legend(loc = "lower left")
