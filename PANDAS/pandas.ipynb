# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("Credit.csv") #Ler os dados em csv

dados.shape #formato (matriz)
# Out:
# (1000, 21)

# %%
dados.describe() #resumo estatistico
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
dados.head() # 5 primeiras linhas
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
dados.tail(3)  # 3 ultimos registros
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 997   'no checking'        12                   'existing paid'    radio/tv
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 997            804           <100         >=7                       4
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 997   'male single'          none  ...                  car  38
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# ...

# %%
dados[["duration"]] #filtrar colunas
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
dados.loc[1:3] #linhas 1 a 3
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
#
#    property_magnitude age  other_payment_plans     housing existing_credits  \
# 1       'real estate'  22                 none         own                1
# ...

# %%
dados.loc[[1,3]]#linhas 1 e 3
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 1           5951           <100     1<=X<4                       2
# 3           7882           <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 3         'male single'     guarantor  ...    'life insurance'  45
#
#    other_payment_plans     housing existing_credits      job num_dependents  \
# 1                 none         own                1  skilled              1
# 3                 none  'for free'                1  skilled              2
#
#    own_telephone foreign_worker class
# 1           none            yes   bad
# 3           none            yes  good
#
# ...

# %%
dados.loc[dados["duration"]==48] # todos os dados com 48 na coluna duration
# Out:
#     checking_status  duration                    credit_history  \
# 1          0<=X<200        48                   'existing paid'
# 11               <0        48                   'existing paid'
# 36    'no checking'        48  'critical/other existing credit'
# 44               <0        48  'critical/other existing credit'
# 63         0<=X<200        48             'no credits/all paid'
# 115   'no checking'        48  'critical/other existing credit'
# 130        0<=X<200        48                   'existing paid'
# 145        0<=X<200        48                        'all paid'
# 191        0<=X<200        48             'no credits/all paid'
# 226        0<=X<200        48                   'existing paid'
# 242              <0        48             'no credits/all paid'
# 272        0<=X<200        48                        'all paid'
# 273        0<=X<200        48                   'existing paid'
# 286              <0        48                   'existing paid'
# ...

# %%
dados.loc[dados["credit_amount"]>18000]
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
credit = dados[["checking_status","duration"]].loc[dados["credit_amount"] > 18000]
print(credit)
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
s = pd.Series([1, 2,4,6,7,8,2])
print(s)
# Out:
# 0    1
# 1    2
# 2    4
# 3    6
# 4    7
# 5    8
# 6    2
# dtype: int64

# %%
n = np.array([2,3,4,678])
s = pd.Series(n)
print(s)
# Out:
# 0      2
# 1      3
# 2      4
# 3    678
# dtype: int64

# %%
dados.rename(columns={"duration":"duraçao", "purpose":"proposito"},inplace=True)
dados.head(1)
# Out:
#   checking_status  duraçao                    credit_history proposito  \
# 0              <0        6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
dados.drop("credit_history",axis=1,inplace=True)
dados.head()
# Out:
#    duraçao            proposito  credit_amount      savings_status  \
# 0        6             radio/tv           1169  'no known savings'
# 1       48             radio/tv           5951                <100
# 2       12            education           2096                <100
# 3       42  furniture/equipment           7882                <100
# 4       24            'new car'           4870                <100
#
#    installment_commitment       personal_status other_parties  \
# 0                       4         'male single'          none
# 1                       2  'female div/dep/mar'          none
# 2                       2         'male single'          none
# 3                       2         'male single'     guarantor
# 4                       3         'male single'          none
#
#    residence_since   property_magnitude  age other_payment_plans     housing  \
# 0                4        'real estate'   67                none         own
# ...

# %%
dados.isnull()
dados.isnull().sum()
# Out:
# duraçao                   0
# proposito                 0
# credit_amount             0
# savings_status            0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
dados.dropna()
# Out:
#      duraçao            proposito  credit_amount      savings_status  \
# 0          6             radio/tv           1169  'no known savings'
# 1         48             radio/tv           5951                <100
# 2         12            education           2096                <100
# 3         42  furniture/equipment           7882                <100
# 4         24            'new car'           4870                <100
# ..       ...                  ...            ...                 ...
# 995       12  furniture/equipment           1736                <100
# 996       30           'used car'           3857                <100
# 997       12             radio/tv            804                <100
# 998       45             radio/tv           1845                <100
# 999       45           'used car'           4576          100<=X<500
#
#      installment_commitment       personal_status other_parties  \
# 0                         4         'male single'          none
# ...

# %%
dados.iloc[0:3, 0:5]
# Out:
#    duraçao  proposito  credit_amount      savings_status  \
# 0        6   radio/tv           1169  'no known savings'
# 1       48   radio/tv           5951                <100
# 2       12  education           2096                <100
#
#    installment_commitment
# 0                       4
# 1                       2
# 2                       2

# %%
dados.iloc[[3, 45,67,876], 0:5]
# Out:
#      duraçao            proposito  credit_amount savings_status  \
# 3         42  furniture/equipment           7882           <100
# 45        11            'new car'           1393           <100
# 67        12            'new car'           1007         >=1000
# 876       18             radio/tv           1940           <100
#
#      installment_commitment
# 3                         2
# 45                        4
# 67                        4
# 876                       3
