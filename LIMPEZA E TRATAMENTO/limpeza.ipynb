# %%
import pandas as pd
import seaborn as srn
import statistics  as sts

# %%
dataset = pd.read_csv("Churn.csv", sep = ";")

dataset.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
dataset.shape
# Out:
# (999, 12)

# %%
dataset.columns = ["Id", "Score", "Estado", "Genero", "Idade", "Patrimonio", "Saldo", "Produtos", "TemCredito", 
                   "Ativo", "Salario", "Saiu"]

# %%
dataset.head()
# Out:
#    Id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCredito  Ativo     Salario  Saiu
# 0           1      1  10134888.0     1
# 1           0      1  11254258.0     0
# 2           1      0  11393157.0     1
# 3           0      0   9382663.0     0
# 4           1      1    790841.0     0

# %%
agrupado = dataset.groupby(["Estado"]).size()
agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
agrupado.plot.bar(color="Blue")
# Out:
# <Axes: xlabel='Estado'>

# %%
agpgen = dataset.groupby(["Genero"]).size()
agpgen
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
agpgen.plot.bar(color="Red")
# Out:
# <Axes: xlabel='Genero'>

# %%
#explorar colunas numericas

dataset["Score"].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: Score, dtype: float64

# %%
srn.boxplot(dataset["Score"]).set_title("Score")
# Out:
# Text(0.5, 1.0, 'Score')

# %%
srn.distplot(dataset["Score"]).set_title("Score")
# Out:
# /tmp/ipykernel_11477/2783977998.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset["Score"]).set_title("Score")
# Text(0.5, 1.0, 'Score')

# %%
dataset["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dataset["Idade"]).set_title("Idade")
# Out:
# Text(0.5, 1.0, 'Idade')

# %%
srn.distplot(dataset["Idade"]).set_title("Idade")
# Out:
# /tmp/ipykernel_11477/724680528.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset["Idade"]).set_title("Idade")
# Text(0.5, 1.0, 'Idade')

# %%
dataset["Saldo"].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
srn.boxplot(dataset["Saldo"]).set_title("Saldo")
# Out:
# Text(0.5, 1.0, 'Saldo')

# %%
srn.distplot(dataset["Saldo"]).set_title("Saldo")
# Out:
# /tmp/ipykernel_11477/1711996747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset["Saldo"]).set_title("Saldo")
# Text(0.5, 1.0, 'Saldo')

# %%
dataset["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
srn.distplot(dataset["Salario"]).set_title("Salario")
# Out:
# /tmp/ipykernel_11477/2215139794.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset["Salario"]).set_title("Salario")
# Text(0.5, 1.0, 'Salario')

# %%
srn.boxplot(dataset["Salario"]).set_title("Salario")
# Out:
# Text(0.5, 1.0, 'Salario')

# %%
dataset.isnull().sum()
# Out:
# Id            0
# Score         0
# Estado        0
# Genero        8
# Idade         0
# Patrimonio    0
# Saldo         0
# Produtos      0
# TemCredito    0
# Ativo         0
# Salario       7
# Saiu          0
# dtype: int64

# %%
dataset["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
mediana = sts.median(dataset["Salario"])
mediana
# Out:
# 70518.0

# %%
dataset["Salario"].fillna(mediana, inplace=True)
dataset["Salario"].describe()
# Out:
# /tmp/ipykernel_11477/2249486181.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Salario"].fillna(mediana, inplace=True)
# count    9.990000e+02
# mean     3.504085e+07
# std      5.287241e+08
# min      9.677000e+03
# 25%      2.856485e+06
# 50%      8.641028e+06
# 75%      1.402954e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
dataset.isnull().sum()
# Out:
# Id            0
# Score         0
# Estado        0
# Genero        8
# Idade         0
# Patrimonio    0
# Saldo         0
# Produtos      0
# TemCredito    0
# Ativo         0
# Salario       0
# Saiu          0
# dtype: int64

# %%
agrup = dataset.groupby(["Genero"]).size()
agrup
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
dataset["Genero"].isnull().sum()
# Out:
# np.int64(8)

# %%
dataset["Genero"].fillna("Masculino", inplace=True)
# Out:
# /tmp/ipykernel_11477/1787080657.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Genero"].fillna("Masculino", inplace=True)

# %%
dataset.loc[dataset["Genero"] == 'M', "Genero"] = "Masculino"
dataset.loc[dataset["Genero"].isin(["F", "Fem"]), "Genero"] = "Feminino"
agrup = dataset.groupby(["Genero"]).size()
agrup
# Out:
# Genero
# Feminino     464
# Masculino    535
# dtype: int64

# %%
dataset["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
dataset.loc[(dataset["Idade"]<0) | (dataset["Idade"]>120)]
# Out:
#       Id  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 867  869    636     RS   Feminino    -10           1  17083346         1
# 984  986    773     RS  Masculino    -20           1  12453278         2
# 990  992    655     RS  Masculino    140           5     93147         2
#
#      TemCredito  Ativo     Salario  Saiu genero
# 867           1      0  11051028.0     1    NaN
# 984           0      1   1172357.0     0    NaN
# 990           1      0   6621413.0     0    NaN

# %%
mediana = sts.median(dataset["Idade"])
mediana
# Out:
# 37

# %%
dataset.loc[(dataset["Idade"]<0) | (dataset["Idade"]>120), "Idade"] = mediana

# %%
dataset.loc[(dataset["Idade"]<0) | (dataset["Idade"]>120)]
# Out:
# Empty DataFrame
# Columns: [Id, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCredito, Ativo, Salario, Saiu, genero]
# Index: []

# %%
dataset[dataset.duplicated(["Id"], keep = False)]
# Out:
#     Id  Score Estado    Genero  Idade  Patrimonio    Saldo  Produtos  \
# 80  81    665     RS  Feminino     34           1  9664554         2
# 81  81    665     RS  Feminino     34           1  9664554         2
#
#     TemCredito  Ativo     Salario  Saiu genero
# 80           0      0  17141366.0     0    NaN
# 81           0      0  17141366.0     0    NaN

# %%
dataset.drop_duplicates(subset="Id", keep='first', inplace= True)

# %%
dataset[dataset.duplicated(["Id"], keep = False)]
# Out:
# Empty DataFrame
# Columns: [Id, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCredito, Ativo, Salario, Saiu, genero]
# Index: []

# %%
agrup = dataset.groupby(["Estado"]).size()
agrup
# Out:
# Estado
# PR    257
# RP      1
# RS    477
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
mode = sts.mode(dataset["Estado"])
mode
# Out:
# 'RS'

# %%
dataset.loc[dataset["Estado"].isin(["RP","SP","TD"]), "Estado"] = mode

# %%
agrup = dataset.groupby(["Estado"]).size()
agrup
# Out:
# Estado
# PR    257
# RS    483
# SC    258
# dtype: int64

# %%
dataset["Salario"].describe()
# Out:
# count    9.980000e+02
# mean     3.505879e+07
# std      5.289889e+08
# min      9.677000e+03
# 25%      2.849010e+06
# 50%      8.637196e+06
# 75%      1.401381e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
stdev = sts.stdev(dataset["Salario"])
stdev
# Out:
# 528988918.4679201

# %%
dataset.loc[dataset["Salario"] > 2*stdev]
# Out:
#       Id  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 7      8    376     PR   Feminino     29           4  11504674         4
# 116  118    668     PR   Feminino     37           6   1678644         1
# 170  172    484     RS   Feminino     29           4  13011439         1
# 230  232    673     RS  Masculino     72           1         0         2
#
#      TemCredito  Ativo       Salario  Saiu genero
# 7             1      0  1.193469e+10     1    NaN
# 116           1      0  1.156383e+10     0    NaN
# 170           1      0  1.640179e+09     0    NaN
# 230           0      1  1.119812e+09     0    NaN

# %%
mediana = sts.median(dataset["Salario"])
print(mediana)
dataset.loc[dataset["Salario"] > 2*stdev, "Salario"] = mediana
# Out:
# 8635279.25

# %%
dataset.loc[dataset["Salario"] > 2*stdev]
# Out:
# Empty DataFrame
# Columns: [Id, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCredito, Ativo, Salario, Saiu, genero]
# Index: []

# %%
dataset.head()
# Out:
#    Id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCredito  Ativo     Salario  Saiu genero
# 0           1      1  10134888.0     1    NaN
# 1           0      1  11254258.0     0    NaN
# 2           1      0  11393157.0     1    NaN
# 3           0      0   9382663.0     0    NaN
# 4           1      1    790841.0     0    NaN

# %%
dataset.shape
# Out:
# (998, 13)
